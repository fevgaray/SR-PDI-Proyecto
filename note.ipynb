# %% [markdown]
# # Proyecto PDI: Super Resolution

# %% [markdown]
# ## Seccion 1: Super resolution

# %% [markdown]
# Bienvenido a Super Resolution!
#
# Instrucciones de uso:
# - Coloque todas las imágenes que desee en algunas de las sub carpetas de "ImagesLR", es de cir ("2x","3x","4x"), dependiendo en cuanta resolucion le quiera aumentar a la imágen.
#
#   _Recomendado:_ No mas de 5 imagenes a la vez, y entre mas alta la resolucion de las imagenes mas tiempo toma el procesamiento.
# - Una vez terminado el procesamiento, indicado por la celda del notebook, podra acceder a las imagenes resultantes en la carpeta *"dcscn-super-resolution-master/output/dcscn_L12_F196to48_NIN_A64_PS_R1F32"* o en la carpeta donde su nombre incluya Sc3 o Sc4, que son los resultados para las escalas 3x y 4x, respectivamente.
#
# - Ademas, si quiere ver una vista rápida y sencilla de las imágenes que proceso en este mismo notebook se ofrece una celda extra que muestra las imágenes originales y las resultantes.

# %%
# Celda necesaria para el funcionamiento del notebook, importa bibliotecas
import os, glob
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Opciones de Configuracion:

# %%
EscalaResolution = 4 # Por Default 2, si no cambiar por valores como 3 o 4.

# %%
# Busca en las carpetas indicadas por las imagenes a procesar
inputImagenes = []
path = 'ImagesLR/'+ str(EscalaResolution)+ 'x'
for filename in glob.glob(os.path.join(path, '*')):
    inputImagenes.append(filename[12:])
    fileLoc = '../'+ filename

inputImagenes
# Out:
# ['00000035.png', '00000045.png', '00000085.png', '00000110.png', 'HR.png']

# %%
# Va procesando cada imagen indicada y guardando en las carpetas indicadas
inputImagenes = []
path = 'ImagesLR/'+ str(EscalaResolution)+ 'x'
for filename in glob.glob(os.path.join(path, '*')):
    inputImagenes.append(filename[12:])
    fileLoc = '../'+ filename
    # !cd dcscn-super-resolution-master && python sr.py --file={fileLoc} --scale={EscalaResolution}
# Out:
# Python Interpreter version:3.9
# tensorflow version:2.10.0
# numpy version:1.26.1
# Session and graph initialized.
# CNN1/conv_W:0 (3, 3, 1, 196)=1764, CNN1/conv_B:0 196, CNN1/prelu/CNN1_prelu:0 196, CNN2/conv_W:0 (3, 3, 196, 166)=292824, CNN2/conv_B:0 166, CNN2/prelu/CNN2_prelu:0 166, CNN3/conv_W:0 (3, 3, 166, 148)=221112, CNN3/conv_B:0 148, CNN3/prelu/CNN3_prelu:0 148, CNN4/conv_W:0 (3, 3, 148, 133)=177156, CNN4/conv_B:0 133, CNN4/prelu/CNN4_prelu:0 133, CNN5/conv_W:0 (3, 3, 133, 120)=143640, CNN5/conv_B:0 120, CNN5/prelu/CNN5_prelu:0 120, CNN6/conv_W:0 (3, 3, 120, 108)=116640, CNN6/conv_B:0 108, CNN6/prelu/CNN6_prelu:0 108, CNN7/conv_W:0 (3, 3, 108, 97)=94284, CNN7/conv_B:0 97, CNN7/prelu/CNN7_prelu:0 97, CNN8/conv_W:0 (3, 3, 97, 86)=75078, CNN8/conv_B:0 86, CNN8/prelu/CNN8_prelu:0 86, CNN9/conv_W:0 (3, 3, 86, 76)=58824, CNN9/conv_B:0 76, CNN9/prelu/CNN9_prelu:0 76, CNN10/conv_W:0 (3, 3, 76, 66)=45144, CNN10/conv_B:0 66, CNN10/prelu/CNN10_prelu:0 66, CNN11/conv_W:0 (3, 3, 66, 57)=33858, CNN11/conv_B:0 57, CNN11/prelu/CNN11_prelu:0 57, CNN12/conv_W:0 (3, 3, 57, 48)=24624, CNN12/conv_B:0 48, CNN12/prelu/CNN12_prelu:0 48, A1/conv_W:0 (1, 1, 1301, 64)=83264, A1/conv_B:0 64, A1/prelu/A1_prelu:0 64, B1/conv_W:0 (1, 1, 1301, 32)=41632, B1/conv_B:0 32, B1/prelu/B1_prelu:0 32, B2/conv_W:0 (3, 3, 32, 32)=9216, B2/conv_B:0 32, B2/prelu/B2_prelu:0 32, Up-PS/Up-PS_CNN/conv_W:0 (3, 3, 96, 384)=331776, Up-PS/Up-PS_CNN/conv_B:0 384, Up-PS2/Up-PS2_CNN/conv_W:0 (3, 3, 96, 384)=331776, Up-PS2/Up-PS2_CNN/conv_B:0 384, R-CNN1/conv_W:0 (3, 3, 96, 1)=864,
# Total 50 variables, 2,087,102 params
# Model initialized.
# Model restored [ models/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32.ckpt ].
# Loaded [../ImagesLR/4x\00000035.png]: 480 x 270 x 3
# Saved [output/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32/00000035.png]
# Saved [output/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32/00000035_bicubic.png]
# Saved [output/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32/00000035_bicubic_y.png]
# Saved [output/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32/00000035_result_y.png]
# Saved [output/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32/00000035_result.png]
# 2023-11-20 22:16:05.070986: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-20 22:16:05.071896: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
#
# DCSCN v2-------------------------------------
# 2023/11/20 22:16:5 [dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32]
# Feature:196 166 148 133 120 108 97 86 76 66 57 48  Total: (1301)64 32 32 384 384 1  Complexity:2,087,102 Receptive Fields:31
# 2023-11-20 22:16:11.730405: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# Python Interpreter version:3.9
# tensorflow version:2.10.0
# numpy version:1.26.1
# Session and graph initialized.
# CNN1/conv_W:0 (3, 3, 1, 196)=1764, CNN1/conv_B:0 196, CNN1/prelu/CNN1_prelu:0 196, CNN2/conv_W:0 (3, 3, 196, 166)=292824, CNN2/conv_B:0 166, CNN2/prelu/CNN2_prelu:0 166, CNN3/conv_W:0 (3, 3, 166, 148)=221112, CNN3/conv_B:0 148, CNN3/prelu/CNN3_prelu:0 148, CNN4/conv_W:0 (3, 3, 148, 133)=177156, CNN4/conv_B:0 133, CNN4/prelu/CNN4_prelu:0 133, CNN5/conv_W:0 (3, 3, 133, 120)=143640, CNN5/conv_B:0 120, CNN5/prelu/CNN5_prelu:0 120, CNN6/conv_W:0 (3, 3, 120, 108)=116640, CNN6/conv_B:0 108, CNN6/prelu/CNN6_prelu:0 108, CNN7/conv_W:0 (3, 3, 108, 97)=94284, CNN7/conv_B:0 97, CNN7/prelu/CNN7_prelu:0 97, CNN8/conv_W:0 (3, 3, 97, 86)=75078, CNN8/conv_B:0 86, CNN8/prelu/CNN8_prelu:0 86, CNN9/conv_W:0 (3, 3, 86, 76)=58824, CNN9/conv_B:0 76, CNN9/prelu/CNN9_prelu:0 76, CNN10/conv_W:0 (3, 3, 76, 66)=45144, CNN10/conv_B:0 66, CNN10/prelu/CNN10_prelu:0 66, CNN11/conv_W:0 (3, 3, 66, 57)=33858, CNN11/conv_B:0 57, CNN11/prelu/CNN11_prelu:0 57, CNN12/conv_W:0 (3, 3, 57, 48)=24624, CNN12/conv_B:0 48, CNN12/prelu/CNN12_prelu:0 48, A1/conv_W:0 (1, 1, 1301, 64)=83264, A1/conv_B:0 64, A1/prelu/A1_prelu:0 64, B1/conv_W:0 (1, 1, 1301, 32)=41632, B1/conv_B:0 32, B1/prelu/B1_prelu:0 32, B2/conv_W:0 (3, 3, 32, 32)=9216, B2/conv_B:0 32, B2/prelu/B2_prelu:0 32, Up-PS/Up-PS_CNN/conv_W:0 (3, 3, 96, 384)=331776, Up-PS/Up-PS_CNN/conv_B:0 384, Up-PS2/Up-PS2_CNN/conv_W:0 (3, 3, 96, 384)=331776, Up-PS2/Up-PS2_CNN/conv_B:0 384, R-CNN1/conv_W:0 (3, 3, 96, 1)=864,
# Total 50 variables, 2,087,102 params
# Model initialized.
# Model restored [ models/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32.ckpt ].
# Loaded [../ImagesLR/4x\00000045.png]: 480 x 270 x 3
# Saved [output/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32/00000045.png]
# Saved [output/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32/00000045_bicubic.png]
# Saved [output/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32/00000045_bicubic_y.png]
# Saved [output/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32/00000045_result_y.png]
# Saved [output/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32/00000045_result.png]
# 2023-11-20 22:17:07.456829: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-20 22:17:07.457766: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
#
# DCSCN v2-------------------------------------
# 2023/11/20 22:17:7 [dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32]
# Feature:196 166 148 133 120 108 97 86 76 66 57 48  Total: (1301)64 32 32 384 384 1  Complexity:2,087,102 Receptive Fields:31
# 2023-11-20 22:17:13.758054: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# Python Interpreter version:3.9
# tensorflow version:2.10.0
# numpy version:1.26.1
# Session and graph initialized.
# CNN1/conv_W:0 (3, 3, 1, 196)=1764, CNN1/conv_B:0 196, CNN1/prelu/CNN1_prelu:0 196, CNN2/conv_W:0 (3, 3, 196, 166)=292824, CNN2/conv_B:0 166, CNN2/prelu/CNN2_prelu:0 166, CNN3/conv_W:0 (3, 3, 166, 148)=221112, CNN3/conv_B:0 148, CNN3/prelu/CNN3_prelu:0 148, CNN4/conv_W:0 (3, 3, 148, 133)=177156, CNN4/conv_B:0 133, CNN4/prelu/CNN4_prelu:0 133, CNN5/conv_W:0 (3, 3, 133, 120)=143640, CNN5/conv_B:0 120, CNN5/prelu/CNN5_prelu:0 120, CNN6/conv_W:0 (3, 3, 120, 108)=116640, CNN6/conv_B:0 108, CNN6/prelu/CNN6_prelu:0 108, CNN7/conv_W:0 (3, 3, 108, 97)=94284, CNN7/conv_B:0 97, CNN7/prelu/CNN7_prelu:0 97, CNN8/conv_W:0 (3, 3, 97, 86)=75078, CNN8/conv_B:0 86, CNN8/prelu/CNN8_prelu:0 86, CNN9/conv_W:0 (3, 3, 86, 76)=58824, CNN9/conv_B:0 76, CNN9/prelu/CNN9_prelu:0 76, CNN10/conv_W:0 (3, 3, 76, 66)=45144, CNN10/conv_B:0 66, CNN10/prelu/CNN10_prelu:0 66, CNN11/conv_W:0 (3, 3, 66, 57)=33858, CNN11/conv_B:0 57, CNN11/prelu/CNN11_prelu:0 57, CNN12/conv_W:0 (3, 3, 57, 48)=24624, CNN12/conv_B:0 48, CNN12/prelu/CNN12_prelu:0 48, A1/conv_W:0 (1, 1, 1301, 64)=83264, A1/conv_B:0 64, A1/prelu/A1_prelu:0 64, B1/conv_W:0 (1, 1, 1301, 32)=41632, B1/conv_B:0 32, B1/prelu/B1_prelu:0 32, B2/conv_W:0 (3, 3, 32, 32)=9216, B2/conv_B:0 32, B2/prelu/B2_prelu:0 32, Up-PS/Up-PS_CNN/conv_W:0 (3, 3, 96, 384)=331776, Up-PS/Up-PS_CNN/conv_B:0 384, Up-PS2/Up-PS2_CNN/conv_W:0 (3, 3, 96, 384)=331776, Up-PS2/Up-PS2_CNN/conv_B:0 384, R-CNN1/conv_W:0 (3, 3, 96, 1)=864,
# Total 50 variables, 2,087,102 params
# Model initialized.
# Model restored [ models/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32.ckpt ].
# Loaded [../ImagesLR/4x\00000085.png]: 480 x 270 x 3
# Saved [output/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32/00000085.png]
# Saved [output/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32/00000085_bicubic.png]
# Saved [output/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32/00000085_bicubic_y.png]
# Saved [output/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32/00000085_result_y.png]
# Saved [output/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32/00000085_result.png]
# 2023-11-20 22:18:03.786730: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-20 22:18:03.787671: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
#
# DCSCN v2-------------------------------------
# 2023/11/20 22:18:3 [dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32]
# Feature:196 166 148 133 120 108 97 86 76 66 57 48  Total: (1301)64 32 32 384 384 1  Complexity:2,087,102 Receptive Fields:31
# 2023-11-20 22:18:10.076151: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# 2023-11-20 22:19:00.355671: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-20 22:19:00.356699: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
#
# DCSCN v2-------------------------------------
# 2023/11/20 22:19:0 [dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32]
# Feature:196 166 148 133 120 108 97 86 76 66 57 48  Total: (1301)64 32 32 384 384 1  Complexity:2,087,102 Receptive Fields:31
# 2023-11-20 22:19:06.844255: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# Python Interpreter version:3.9
# tensorflow version:2.10.0
# numpy version:1.26.1
# Session and graph initialized.
# CNN1/conv_W:0 (3, 3, 1, 196)=1764, CNN1/conv_B:0 196, CNN1/prelu/CNN1_prelu:0 196, CNN2/conv_W:0 (3, 3, 196, 166)=292824, CNN2/conv_B:0 166, CNN2/prelu/CNN2_prelu:0 166, CNN3/conv_W:0 (3, 3, 166, 148)=221112, CNN3/conv_B:0 148, CNN3/prelu/CNN3_prelu:0 148, CNN4/conv_W:0 (3, 3, 148, 133)=177156, CNN4/conv_B:0 133, CNN4/prelu/CNN4_prelu:0 133, CNN5/conv_W:0 (3, 3, 133, 120)=143640, CNN5/conv_B:0 120, CNN5/prelu/CNN5_prelu:0 120, CNN6/conv_W:0 (3, 3, 120, 108)=116640, CNN6/conv_B:0 108, CNN6/prelu/CNN6_prelu:0 108, CNN7/conv_W:0 (3, 3, 108, 97)=94284, CNN7/conv_B:0 97, CNN7/prelu/CNN7_prelu:0 97, CNN8/conv_W:0 (3, 3, 97, 86)=75078, CNN8/conv_B:0 86, CNN8/prelu/CNN8_prelu:0 86, CNN9/conv_W:0 (3, 3, 86, 76)=58824, CNN9/conv_B:0 76, CNN9/prelu/CNN9_prelu:0 76, CNN10/conv_W:0 (3, 3, 76, 66)=45144, CNN10/conv_B:0 66, CNN10/prelu/CNN10_prelu:0 66, CNN11/conv_W:0 (3, 3, 66, 57)=33858, CNN11/conv_B:0 57, CNN11/prelu/CNN11_prelu:0 57, CNN12/conv_W:0 (3, 3, 57, 48)=24624, CNN12/conv_B:0 48, CNN12/prelu/CNN12_prelu:0 48, A1/conv_W:0 (1, 1, 1301, 64)=83264, A1/conv_B:0 64, A1/prelu/A1_prelu:0 64, B1/conv_W:0 (1, 1, 1301, 32)=41632, B1/conv_B:0 32, B1/prelu/B1_prelu:0 32, B2/conv_W:0 (3, 3, 32, 32)=9216, B2/conv_B:0 32, B2/prelu/B2_prelu:0 32, Up-PS/Up-PS_CNN/conv_W:0 (3, 3, 96, 384)=331776, Up-PS/Up-PS_CNN/conv_B:0 384, Up-PS2/Up-PS2_CNN/conv_W:0 (3, 3, 96, 384)=331776, Up-PS2/Up-PS2_CNN/conv_B:0 384, R-CNN1/conv_W:0 (3, 3, 96, 1)=864,
# Total 50 variables, 2,087,102 params
# Model initialized.
# Model restored [ models/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32.ckpt ].
# Loaded [../ImagesLR/4x\00000110.png]: 480 x 270 x 3
# Saved [output/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32/00000110.png]
# Saved [output/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32/00000110_bicubic.png]
# Saved [output/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32/00000110_bicubic_y.png]
# Saved [output/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32/00000110_result_y.png]
# Saved [output/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32/00000110_result.png]
# Python Interpreter version:3.9
# tensorflow version:2.10.0
# numpy version:1.26.1
# Session and graph initialized.
# CNN1/conv_W:0 (3, 3, 1, 196)=1764, CNN1/conv_B:0 196, CNN1/prelu/CNN1_prelu:0 196, CNN2/conv_W:0 (3, 3, 196, 166)=292824, CNN2/conv_B:0 166, CNN2/prelu/CNN2_prelu:0 166, CNN3/conv_W:0 (3, 3, 166, 148)=221112, CNN3/conv_B:0 148, CNN3/prelu/CNN3_prelu:0 148, CNN4/conv_W:0 (3, 3, 148, 133)=177156, CNN4/conv_B:0 133, CNN4/prelu/CNN4_prelu:0 133, CNN5/conv_W:0 (3, 3, 133, 120)=143640, CNN5/conv_B:0 120, CNN5/prelu/CNN5_prelu:0 120, CNN6/conv_W:0 (3, 3, 120, 108)=116640, CNN6/conv_B:0 108, CNN6/prelu/CNN6_prelu:0 108, CNN7/conv_W:0 (3, 3, 108, 97)=94284, CNN7/conv_B:0 97, CNN7/prelu/CNN7_prelu:0 97, CNN8/conv_W:0 (3, 3, 97, 86)=75078, CNN8/conv_B:0 86, CNN8/prelu/CNN8_prelu:0 86, CNN9/conv_W:0 (3, 3, 86, 76)=58824, CNN9/conv_B:0 76, CNN9/prelu/CNN9_prelu:0 76, CNN10/conv_W:0 (3, 3, 76, 66)=45144, CNN10/conv_B:0 66, CNN10/prelu/CNN10_prelu:0 66, CNN11/conv_W:0 (3, 3, 66, 57)=33858, CNN11/conv_B:0 57, CNN11/prelu/CNN11_prelu:0 57, CNN12/conv_W:0 (3, 3, 57, 48)=24624, CNN12/conv_B:0 48, CNN12/prelu/CNN12_prelu:0 48, A1/conv_W:0 (1, 1, 1301, 64)=83264, A1/conv_B:0 64, A1/prelu/A1_prelu:0 64, B1/conv_W:0 (1, 1, 1301, 32)=41632, B1/conv_B:0 32, B1/prelu/B1_prelu:0 32, B2/conv_W:0 (3, 3, 32, 32)=9216, B2/conv_B:0 32, B2/prelu/B2_prelu:0 32, Up-PS/Up-PS_CNN/conv_W:0 (3, 3, 96, 384)=331776, Up-PS/Up-PS_CNN/conv_B:0 384, Up-PS2/Up-PS2_CNN/conv_W:0 (3, 3, 96, 384)=331776, Up-PS2/Up-PS2_CNN/conv_B:0 384, R-CNN1/conv_W:0 (3, 3, 96, 1)=864,
# Total 50 variables, 2,087,102 params
# Model initialized.
# Model restored [ models/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32.ckpt ].
# Loaded [../ImagesLR/4x\HR.png]: 480 x 270 x 3
# Saved [output/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32/HR.png]
# Saved [output/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32/HR_bicubic.png]
# Saved [output/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32/HR_bicubic_y.png]
# Saved [output/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32/HR_result_y.png]
# Saved [output/dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32/HR_result.png]
# 2023-11-20 22:20:01.225501: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-20 22:20:01.226539: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
#
# DCSCN v2-------------------------------------
# 2023/11/20 22:20:1 [dcscn_L12_F196to48_Sc4_NIN_A64_PS_R1F32]
# Feature:196 166 148 133 120 108 97 86 76 66 57 48  Total: (1301)64 32 32 384 384 1  Complexity:2,087,102 Receptive Fields:31
# 2023-11-20 22:20:07.777161: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled

# %%
inputImagenes
# Out:
# ['00000035.png', '00000045.png', '00000085.png', '00000110.png', 'HR.png']

# %%
def mostrar_imagenes_segun_lista(ruta_carpeta, lista_nombres_archivos, EscalaResolution):
    # Obtener la lista de archivos en la carpeta
    archivos = os.listdir(ruta_carpeta)

    # Filtrar solo los archivos de imagen cuyos nombres están en la lista
    archivos_imagen = [archivo for archivo in archivos if archivo in lista_nombres_archivos]

    # Mostrar cada imagen
    for archivo_imagen in archivos_imagen:
        ruta_completa = os.path.join(ruta_carpeta, archivo_imagen)
        archivo_result = ruta_completa[:-4] + '_result' + ruta_completa[-4:]
        # Abrir la imagen con PIL
        imagen1 = Image.open(ruta_completa)
        imagen2 = Image.open(archivo_result)
        # Mostrar la imagen con matplotlib
        f, axarr = plt.subplots(1,2)
        axarr[0].imshow(imagen1)
        axarr[0].set_title("Original")
        axarr[1].imshow(imagen2)
        axarr[1].set_title("Resultado")
        plt.show()


#Ruta de la carpeta que contiene las imágenes
if EscalaResolution == 2:
    ruta_carpeta_imagenes = "dcscn-super-resolution-master/output/dcscn_L12_F196to48_NIN_A64_PS_R1F32"
if EscalaResolution != 2:
    ruta_carpeta_imagenes = "dcscn-super-resolution-master/output/dcscn_L12_F196to48_Sc"+str(EscalaResolution)+"_NIN_A64_PS_R1F32"

    
#Lista de nombres de archivos que deseas mostrar
lista_nombres_archivos = inputImagenes

#Llamar a la función para mostrar las imágenes según la lista de nombres
mostrar_imagenes_segun_lista(ruta_carpeta_imagenes, lista_nombres_archivos, EscalaResolution)

# %% [markdown]
# ## Seccion 2: Herramientas Validación

# %%
import pandas as pd
from skimage.metrics import peak_signal_noise_ratio


def add_to_pandas(df, image_real, image_test, image_num, scale):
    psnr = peak_signal_noise_ratio(image_real, image_test)
    print(psnr, image_num, scale)
    new_row = {'Image #': image_num, 'Scale': scale, 'PSNR':psnr}
    df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)
    return df


def calcular_PSNR_All(lista_nombres_archivos):

    df = pd.DataFrame()
    df['Image #'] = []
    df['Scale'] = []
    df['PSNR'] = []

    #Obtener la lista de carpetas en los outputs de las 3 escalas 
    carpetasOutput = os.listdir('dcscn-super-resolution-master/output')

    #Obtener images true HR que despues se van a analizar con PSNR en escalas x2 x3 x4
    imagenesHR = os.listdir('ImagesHR')

    
    for carpeta in carpetasOutput:
        # Direccion que se utilizara para obtener direccion de cada imagen resultante por cada escala
        archivos = os.listdir('dcscn-super-resolution-master/output/'+ carpeta)

        # Filtrar solo los archivos de imagen cuyos nombres están en la lista
        archivos_imagen = [archivo for archivo in archivos if archivo in lista_nombres_archivos]
        print(archivos_imagen)
        
        for imagen in archivos_imagen:
            ruta_completa = os.path.join('dcscn-super-resolution-master/output',carpeta, imagen)
            #print(ruta_completa)
            archivo_result = ruta_completa[:-4] + '_result' + ruta_completa[-4:]

            #Abrir cada imagen para calcular PSNR
            imgHR = Image.open('ImagesHR/'+ imagen)
            a = np.asarray(imgHR)
            imgSR = Image.open(archivo_result)
            b = np.asarray(imgSR)

            imgNum = lista_nombres_archivos.index(imagen)+1
            scale = carpetasOutput.index(carpeta)+2
            
            df = add_to_pandas(df, a, b, imgNum, scale)
            #print(peak_signal_noise_ratio(a,b))

    return df

theDF = calcular_PSNR_All(inputImagenes)
# Out:
# ['00000035.png', '00000045.png', '00000085.png', '00000110.png', 'HR.png']
# 29.638301404767308 1 2
# 25.67540915327935 2 2
# 40.55381262673207 3 2
# 29.593143162144194 4 2
# 29.302883566285303 5 2
# ['00000035.png', '00000045.png', '00000085.png', '00000110.png', 'HR.png']
# 35.76151143507217 1 3
# 26.42056313284933 2 3
# 26.794314406956996 3 3
# 25.306821233592657 4 3
# 34.41126017688478 5 3
# ['00000035.png', '00000045.png', '00000085.png', '00000110.png', 'HR.png']
# 26.549009422724588 1 4
# 23.515434073590722 2 4
# 24.265960560678046 3 4
# 33.15248509004028 4 4
# 26.217657602513196 5 4

# %%
print(theDF)
# Out:
#     Image #  Scale       PSNR
# 0       1.0    2.0  29.638301
# 1       2.0    2.0  25.675409
# 2       3.0    2.0  40.553813
# 3       4.0    2.0  29.593143
# 4       5.0    2.0  29.302884
# 5       1.0    3.0  35.761511
# 6       2.0    3.0  26.420563
# 7       3.0    3.0  26.794314
# 8       4.0    3.0  25.306821
# 9       5.0    3.0  34.411260
# 10      1.0    4.0  26.549009
# 11      2.0    4.0  23.515434
# 12      3.0    4.0  24.265961
# 13      4.0    4.0  33.152485
# 14      5.0    4.0  26.217658

# %%
#Tabla ordenada por imagenes
sorted_df = theDF.sort_values(by='Image #')
sorted_df.to_csv('output.csv', index=False)
sorted_df
# Out:
#     Image #  Scale       PSNR
# 0       1.0    2.0  29.638301
# 5       1.0    3.0  35.761511
# 10      1.0    4.0  26.549009
# 1       2.0    2.0  25.675409
# 6       2.0    3.0  26.420563
# 11      2.0    4.0  23.515434
# 2       3.0    2.0  40.553813
# 7       3.0    3.0  26.794314
# 12      3.0    4.0  24.265961
# 3       4.0    2.0  29.593143
# 8       4.0    3.0  25.306821
# 13      4.0    4.0  33.152485
# 4       5.0    2.0  29.302884
# 9       5.0    3.0  34.411260
# 14      5.0    4.0  26.217658

# %%
#Codigo para obtener PSNR promedio de cada escala
df_avg = theDF
result_df = df_avg.groupby('Scale')['PSNR'].mean().reset_index()

print(result_df)
# Out:
#    Scale       PSNR
# 0    2.0  30.952710
# 1    3.0  29.738894
# 2    4.0  26.740109

# %%
# Codigo para utilizar herramientas pixelmatch de js... (Trabajo en proceso)
import execjs
from PIL import Image

# Replace 'path/to/script.js' with the actual path to your JavaScript file
js_script_path = 'pixelmatch/index.js'

try:
    # Load and execute the JavaScript script using PyExecJS
    ctx = execjs.compile(open(js_script_path).read())
    img1 = str(Image.open('HR.png'))
    a = np.asarray(img1)
    img2 = str(Image.open('LR.png'))
    b = np.asarray(img2)
    
    print(ctx.call('pixelmatch', img1, img2, 'null', 1920, 800, '{threshold: 0.1}'))

except Exception as e:
    print(f"Error executing JavaScript script: {e}")
# Out:
# Error executing JavaScript script: Error: Image data: Uint8Array, Uint8ClampedArray or Buffer expected.
